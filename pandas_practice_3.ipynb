# %% [markdown]
# # Pandas practice

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %% [markdown]
# # Energy Indicators.xls

# %%
Energy=pd.read_excel('data/2/Energy Indicators.xls')
Energy.head(10)
# Out:
#    Unnamed: 0 Unnamed: 1                                         Unnamed: 2  \
# 0         NaN        NaN                   Environmental Indicators: Energy
# 1         NaN        NaN                                                NaN
# 2         NaN        NaN  Energy Supply and Renewable Electricity Produc...
# 3         NaN        NaN                                                NaN
# 4         NaN        NaN                                                NaN
# 5         NaN        NaN                                                NaN
# 6         NaN        NaN  Choose a country from the following drop-down ...
# 7         NaN        NaN                                                NaN
# 8         NaN        NaN                                            Country
# 9         NaN        NaN                                                NaN
#
#       Unnamed: 3                Unnamed: 4                        Unnamed: 5
# ...

# %% [markdown]
# Excel 파일 정리

# %%
Energy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 282 entries, 0 to 281
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  0 non-null      float64
#  1   Unnamed: 1  260 non-null    object
#  2   Unnamed: 2  252 non-null    object
#  3   Unnamed: 3  232 non-null    object
#  4   Unnamed: 4  232 non-null    object
#  5   Unnamed: 5  235 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 13.3+ KB

# %%
Energy= Energy.drop(['Unnamed: 0','Unnamed: 1'], axis=1)
Energy.head(30)
# Out:
#                                            Unnamed: 2     Unnamed: 3  \
# 0                    Environmental Indicators: Energy            NaN
# 1                                                 NaN            NaN
# 2   Energy Supply and Renewable Electricity Produc...            NaN
# 3                                                 NaN            NaN
# 4                                                 NaN            NaN
# 5                                                 NaN            NaN
# 6   Choose a country from the following drop-down ...            NaN
# 7                                                 NaN            NaN
# 8                                             Country  Energy Supply
# 9                                                 NaN     Petajoules
# 10                                            Andorra              9
# 11                                                NaN            NaN
# 12                                                NaN            NaN
# ...

# %%
Energy= Energy.iloc[17:244]
Energy.head(10)
# Out:
#              Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 17          Afghanistan        321         10    78.6693
# 18              Albania        102         35        100
# 19              Algeria       1959         51    0.55101
# 20       American Samoa        ...        ...   0.641026
# 21              Andorra          9        121    88.6957
# 22               Angola        642         27    70.9091
# 23             Anguilla          2        136          0
# 24  Antigua and Barbuda          8         84          0
# 25            Argentina       3378         79    24.0645
# 26              Armenia        143         48    28.2361

# %%
column_name=['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']
Energy.columns=column_name

# %%
Energy.index = np.arange(1,len(Energy)+1)

# %%
Energy.head(10)
# Out:
#                 Country Energy Supply Energy Supply per Capita % Renewable
# 1           Afghanistan           321                       10     78.6693
# 2               Albania           102                       35         100
# 3               Algeria          1959                       51     0.55101
# 4        American Samoa           ...                      ...    0.641026
# 5               Andorra             9                      121     88.6957
# 6                Angola           642                       27     70.9091
# 7              Anguilla             2                      136           0
# 8   Antigua and Barbuda             8                       84           0
# 9             Argentina          3378                       79     24.0645
# 10              Armenia           143                       48     28.2361

# %%
Energy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 227 entries, 1 to 227
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Country                   227 non-null    object
#  1   Energy Supply             227 non-null    object
#  2   Energy Supply per Capita  227 non-null    object
#  3   % Renewable               227 non-null    object
# dtypes: object(4)
# memory usage: 8.9+ KB

# %% [markdown]
# 'Country'에 숫자 혹은 괄호가 포함되는 것들 삭제 (e.g. 'Bolivia (Plurinational State of)', 'Switzerland17')
#
# 밑의 국가 이름 변경
# ```"Republic of Korea": "South Korea",
# "United States of America": "United States",
# "United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
# "China, Hong Kong Special Administrative Region": "Hong Kong"```

# %%
Energy.replace({'Country': r"[0-9]+"}, {'Country': ""}, regex=True, inplace=True)
Energy.replace({'Country': " \([A-z ]+\)"}, {'Country': ""}, regex=True, inplace=True)

# %%
Energy.replace({'Republic of Korea': 'South Korea',
              'United States of America': 'United States',
              'United Kingdom of Great Britain and Northern Ireland': 'United Kingdom',
              'China, Hong Kong Special Administrative Region': 'Hong Kong'}, inplace=True)

# %% [markdown]
# # world_bank.csv

# %%
GDP=pd.read_csv('data/2/world_bank.csv')
GDP.head(10)
# Out:
#          Data Source World Development Indicators  \
# 0                NaN                          NaN
# 1  Last Updated Date                   2016-07-22
# 2                NaN                          NaN
# 3       Country Name                 Country Code
# 4              Aruba                          ABW
# 5            Andorra                          AND
# 6        Afghanistan                          AFG
# 7             Angola                          AGO
# 8            Albania                          ALB
# 9         Arab World                          ARB
#
#                                  Unnamed: 2      Unnamed: 3  Unnamed: 4  \
# 0                                       NaN             NaN         NaN
# 1                                       NaN             NaN         NaN
# 2                                       NaN             NaN         NaN
# 3                            Indicator Name  Indicator Code      1960.0
# ...

# %%
col_names = GDP.iloc[3]
GDP.columns=col_names

# %%
GDP.head()
# Out:
# 3       Country Name  Country Code                            Indicator Name  \
# 0                NaN           NaN                                       NaN
# 1  Last Updated Date    2016-07-22                                       NaN
# 2                NaN           NaN                                       NaN
# 3       Country Name  Country Code                            Indicator Name
# 4              Aruba           ABW  GDP at market prices (constant 2010 US$)
#
# 3  Indicator Code  1960.0  1961.0  1962.0  1963.0  1964.0  1965.0  ...  \
# 0             NaN     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 1             NaN     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 2             NaN     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 3  Indicator Code  1960.0  1961.0  1962.0  1963.0  1964.0  1965.0  ...
# 4  NY.GDP.MKTP.KD     NaN     NaN     NaN     NaN     NaN     NaN  ...
#
# 3  2006.0  2007.0  2008.0  2009.0        2010.0  2011.0  2012.0  2013.0  \
# ...

# %%
GDP = GDP.iloc[4:]
GDP.index=np.arange(1,len(GDP)+1)

# %%
GDP.head()
# Out:
# 3 Country Name Country Code                            Indicator Name  \
# 1        Aruba          ABW  GDP at market prices (constant 2010 US$)
# 2      Andorra          AND  GDP at market prices (constant 2010 US$)
# 3  Afghanistan          AFG  GDP at market prices (constant 2010 US$)
# 4       Angola          AGO  GDP at market prices (constant 2010 US$)
# 5      Albania          ALB  GDP at market prices (constant 2010 US$)
#
# 3  Indicator Code  1960.0  1961.0  1962.0  1963.0  1964.0  1965.0  ...  \
# 1  NY.GDP.MKTP.KD     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 2  NY.GDP.MKTP.KD     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 3  NY.GDP.MKTP.KD     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 4  NY.GDP.MKTP.KD     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 5  NY.GDP.MKTP.KD     NaN     NaN     NaN     NaN     NaN     NaN  ...
#
# 3        2006.0        2007.0        2008.0        2009.0        2010.0  \
# ...

# %% [markdown]
# Energy, ScimEn 데이터프레임과 join하기 위해 column name 및 국가명 맞추기

# %%
GDP.replace({'Korea, Rep.': 'South Korea',
             'Iran, Islamic Rep.': 'Iran',
             'Hong Kong SAR, China': 'Hong Kong'}, inplace=True)

# %%
GDP = GDP.rename({'Country Name': 'Country'},axis=1)

# %% [markdown]
# 최근 10년 간의 데이터만 사용

# %%
GDP=GDP.drop(GDP.iloc[:, 1:50], axis=1)

# %%
GDP.head(10)
# Out:
# 3                Country        2006.0        2007.0        2008.0  \
# 1                  Aruba           NaN           NaN           NaN
# 2                Andorra  4.018196e+09  4.021331e+09  3.675728e+09
# 3            Afghanistan  1.030523e+10  1.172119e+10  1.214448e+10
# 4                 Angola  5.581103e+10  6.842044e+10  7.787420e+10
# 5                Albania  9.771760e+09  1.034829e+10  1.112752e+10
# 6             Arab World  1.763824e+12  1.863481e+12  1.980983e+12
# 7   United Arab Emirates  2.789489e+11  2.878318e+11  2.970189e+11
# 8              Argentina  3.788140e+11  4.089887e+11  4.215649e+11
# 9                Armenia  8.679746e+09  9.873142e+09  1.055439e+10
# 10        American Samoa           NaN           NaN           NaN
#
# 3         2009.0        2010.0        2011.0        2012.0        2013.0  \
# 1            NaN  2.467704e+09           NaN           NaN           NaN
# 2   3.535389e+09  3.346317e+09  3.185605e+09  3.129538e+09  3.127550e+09
# ...

# %% [markdown]
# # scimagojr-3.xlsx

# %%
ScimEn = pd.read_excel('data/2/scimagojr-3.xlsx')
ScimEn.head()
# Out:
#    Rank             Country  Documents  Citable documents  Citations  \
# 0     1               China     127050             126767     597237
# 1     2       United States      96661              94747     792274
# 2     3               Japan      30504              30287     223024
# 3     4      United Kingdom      20944              20357     206091
# 4     5  Russian Federation      18534              18301      34266
#
#    Self-citations  Citations per document  H index
# 0          411683                    4.70      138
# 1          265436                    8.20      230
# 2           61554                    7.31      134
# 3           37874                    9.84      139
# 4           12422                    1.85       57

# %%
first_join = pd.merge(ScimEn, Energy, how='left', on='Country')

# %%
data=pd.merge(first_join, GDP, how='left', on='Country')

# %%
data = data.set_index('Country')

# %%
final = data.head(15)

# %%
final
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %% [markdown]
# # Q3
#
# Top 15개 국가들의 최근 10년 간의 GDP 평균은 얼마입니까? (내림차순으로 정렬)

# %%
final['sum'] = final.iloc[:,10:].sum(axis=1)
final['avg']=final['sum']/10
final['avg'].sort_values(ascending=False)
# Out:
# <ipython-input-27-08f91ae4eefe>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final['sum'] = final.iloc[:,10:].sum(axis=1)
# <ipython-input-27-08f91ae4eefe>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final['avg']=final['sum']/10
# Country
# United States         1.536434e+13
# China                 6.348609e+12
# Japan                 5.542208e+12
# Germany               3.493025e+12
# France                2.681725e+12
# United Kingdom        2.487907e+12
# ...

# %% [markdown]
# # Q4
#
# 평균 GDP가 6번째로 큰 국가는 10년 동안 GDP가 얼마나 변화했습니까?

# %%
final.sort_values(by='avg', ascending=False)
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# United States          2      96661              94747     792274
# China                  1     127050             126767     597237
# Japan                  3      30504              30287     223024
# Germany                7      17027              16831     140566
# France                 9      13153              12973     130632
# United Kingdom         4      20944              20357     206091
# Brazil                15       8668               8596      60702
# Italy                 11      10964              10794     111850
# India                  8      15005              14841     128763
# Canada                 6      17899              17620     215003
# Russian Federation     5      18534              18301      34266
# Spain                 12       9428               9330     123336
# Australia             14       8831               8725      90765
# ...

# %%
q4 = final.sort_values(by='avg', ascending=False)
q4.iloc[5, 19] - q4.iloc[5, 10]
# Out:
# 246702696075.3999

# %% [markdown]
# # Q5
#
# 1 인당 평균 에너지 공급량은 얼마입니까?

# %%
final['Energy Supply per Capita'].sum()/15
# Out:
# 157.6

# %% [markdown]
# # Q6
#
# '% Renewable' 최대값을 가지는 국가는 어디이며 몇 %입니까?

# %%
q6= final.sort_values(by='% Renewable', ascending=False)

# %%
q6['% Renewable'][0]
# Out:
# 69.64803

# %%
max_renewable = final['% Renewable'].max()

# %%
max_renewable_country = final.index[final['% Renewable']==max_renewable]

# %%
(max_renewable_country, max_renewable)
# Out:
# (Index(['Brazil'], dtype='object', name='Country'), 69.64803)

# %% [markdown]
# # Q7
#
# 'Self-Citations'와 'Total Citations'의 비율을 나타내는 새로운 column을 만드세요.
# 이 새 column의 최대값은 얼마이며 비율이 가장 높은 국가는 어디입니까?

# %%
final['Citations Ratio'] = final['Self-citations']/final['Citations']
# Out:
# <ipython-input-36-15a841ab40d8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final['Citations Ratio'] = final['Self-citations']/final['Citations']

# %%
final
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %%
q7 = final.sort_values(by='Citations Ratio', ascending=False)
q7
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# Russian Federation     5      18534              18301      34266
# United States          2      96661              94747     792274
# Iran                  13       8896               8819      57470
# India                  8      15005              14841     128763
# Japan                  3      30504              30287     223024
# Italy                 11      10964              10794     111850
# Brazil                15       8668               8596      60702
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Germany                7      17027              16831     140566
# Spain                 12       9428               9330     123336
# Canada                 6      17899              17620     215003
# ...

# %%
country = q7.index[0]
ratio = q7['Citations Ratio'][0]
(country, ratio)
# Out:
# ('China', 0.6893126179389422)

# %% [markdown]
# # Q8
#
# 에너지 공급 및 1 인당 에너지 공급을 사용하여 인구를 추정하는 column을 만듭니다. 이 추정치에 따르면 세 번째로 인구가 많은 국가는 어디입니까?

# %% [markdown]
# 인구(Capita) = (에너지공급량) / (1인당 에너지 공급량)

# %%
final['Capita']=final['Energy Supply']/final['Energy Supply per Capita']
# Out:
# <ipython-input-40-b210b3eef28e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final['Capita']=final['Energy Supply']/final['Energy Supply per Capita']

# %%
final
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %%
q8 = final.sort_values(by='Capita', ascending=False)

# %%
country = q8.index[2]
country
# Out:
# 'United States'

# %% [markdown]
# # Q9
#
# 1 인당 인용 가능한 문서 수를 추정하는 열을 만듭니다. 1 인당 인용 가능한 문서 수와 1 인당 에너지 공급 사이의 상관 관계는 무엇입니까? .corr () 메서드 (Pearson의 상관 관계)를 사용합니다.

# %%
final['Citable docs per Capita']= final['Citable documents']/final['Capita']
# Out:
# <ipython-input-44-a493b815152a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final['Citable docs per Capita']= final['Citable documents']/final['Capita']

# %%
final
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %%
q9 = final[['Citable docs per Capita', 'Energy Supply per Capita']]
q9
# Out:
#                    Citable docs per Capita Energy Supply per Capita
# Country
# China                                92.69                       93
# United States                      298.307                      286
# Japan                              237.714                      149
# United Kingdom                     318.721                      124
# Russian Federation                 127.533                      214
# Canada                             500.002                      296
# Germany                             209.42                      165
# India                              11.6242                       26
# France                              203.22                      166
# South Korea                        239.392                      221
# Italy                              180.175                      109
# Spain                               200.89                      106
# Iran                                114.42                      119
# ...

# %%
corr_q9 = q9.astype('float').corr(method='pearson')

# %%
corr_q9
# Out:
#                           Citable docs per Capita  Energy Supply per Capita
# Citable docs per Capita                  1.000000                  0.794001
# Energy Supply per Capita                 0.794001                  1.000000

# %%
c1=q9['Citable docs per Capita'].astype('float')
c2=q9['Energy Supply per Capita'].astype('float')

# %%
c1.corr(c2, method='pearson')
# Out:
# 0.7940010435442945

# %%
final.plot(x='Citable docs per Capita', y='Energy Supply per Capita', kind='scatter')
# Out:
# <AxesSubplot:xlabel='Citable docs per Capita', ylabel='Energy Supply per Capita'>

# %% [markdown]
# # Q10
#
# 국가의 '% Renewable' 값이 상위 15 개 국가의 중앙값 이상이면 1, 국가의 재생 가능 비율 값이 중앙값 미만이면 0으로 새 열을 만듭니다.

# %%
mid_renew = final['% Renewable'].median()

# %%
def highrenew(renew):
    if renew>=mid_renew:
        return 1
    else:
        return 0
    
final['HighRenew'] = final['% Renewable'].apply(lambda x: highrenew(x))
# Out:
# <ipython-input-53-cc70ea160f61>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final['HighRenew'] = final['% Renewable'].apply(lambda x: highrenew(x))

# %%
final['HighRenew']
# Out:
# Country
# China                 1
# United States         0
# Japan                 0
# United Kingdom        0
# Russian Federation    1
# Canada                1
# Germany               1
# India                 0
# France                1
# South Korea           0
# Italy                 1
# Spain                 1
# Iran                  0
# Australia             0
# Brazil                1
# Name: HighRenew, dtype: int64

# %% [markdown]
# # Q11
#
# 다음 dictionary를 사용하여 대륙별로 국가를 그룹화 한 다음 표본 크기 (각 대륙 빈의 국가 수)와 각 국가의 추정 인구에 대한 합계, 평균 및 표준 편차를 표시하는 DataFrame을 만듭니다.
# ```
# ContinentDict  = {'China':'Asia',
#                   'United States':'North America',
#                   'Japan':'Asia',
#                   'United Kingdom':'Europe',
#                   'Russian Federation':'Europe',
#                   'Canada':'North America',
#                   'Germany':'Europe',
#                   'India':'Asia',
#                   'France':'Europe',
#                   'South Korea':'Asia',
#                   'Italy':'Europe',
#                   'Spain':'Europe',
#                   'Iran':'Asia',
#                   'Australia':'Australia',
#                   'Brazil':'South America'}
# ```

# %%
ContinentDict  = {'China':'Asia', 
                  'United States':'North America', 
                  'Japan':'Asia', 
                  'United Kingdom':'Europe', 
                  'Russian Federation':'Europe', 
                  'Canada':'North America', 
                  'Germany':'Europe', 
                  'India':'Asia',
                  'France':'Europe', 
                  'South Korea':'Asia', 
                  'Italy':'Europe', 
                  'Spain':'Europe', 
                  'Iran':'Asia',
                  'Australia':'Australia', 
                  'Brazil':'South America'}

# %%
cont = pd.DataFrame.from_dict(ContinentDict, orient='index', columns=['Continent'])

# %%
q11 = final.join(cont)

# %%
q11
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %%
q11 =q11[['Continent', 'Capita']]
q11
# Out:
#                         Continent   Capita
# Country
# China                        Asia  1367.65
# United States       North America  317.615
# Japan                        Asia  127.409
# United Kingdom             Europe   63.871
# Russian Federation         Europe    143.5
# Canada              North America  35.2399
# Germany                    Europe  80.3697
# India                        Asia  1276.73
# France                     Europe  63.8373
# South Korea                  Asia  49.8054
# Italy                      Europe  59.9083
# Spain                      Europe  46.4434
# Iran                         Asia  77.0756
# Australia               Australia   23.316
# Brazil              South America  205.915

# %%
q11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15 entries, China to Brazil
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Continent  15 non-null     object
#  1   Capita     15 non-null     object
# dtypes: object(2)
# memory usage: 1000.0+ bytes

# %%
q11['Capita'] = pd.to_numeric(q11['Capita'])
# Out:
# <ipython-input-61-06c053b03705>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   q11['Capita'] = pd.to_numeric(q11['Capita'])

# %%
q11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15 entries, China to Brazil
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Continent  15 non-null     object
#  1   Capita     15 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 1000.0+ bytes

# %%
group=q11.groupby(q11['Continent'])

# %%
group_size = group.count().rename(columns={'Capita': 'size'})
group_sum = group.sum().rename(columns={'Capita': 'sum'})
group_mean = group.mean().rename(columns={'Capita': 'mean'})
group_std = group.std().rename(columns={'Capita': 'std'})

# %%
group_sum
# Out:
#                        sum
# Continent
# Asia           2898.666387
# Australia        23.316017
# Europe          457.929667
# North America   352.855249
# South America   205.915254

# %%
continent = group_size.join(group_sum).join(group_mean).join(group_std)

# %%
continent
# Out:
#                size          sum        mean         std
# Continent
# Asia              5  2898.666387  579.733277  679.097888
# Australia         1    23.316017   23.316017         NaN
# Europe            6   457.929667   76.321611   34.647667
# North America     2   352.855249  176.427625  199.669645
# South America     1   205.915254  205.915254         NaN

# %% [markdown]
# # Q12
#
# '% Renewable'을 5 개의 bins로 자릅니다. Top15 국가들을 대륙 별 및 새로운 '% Renewable' bins로 그룹화하세요. 각 그룹에 몇 개의 국가가 있습니까?

# %%
final['Grade']=pd.cut(final['% Renewable'],bins=5,labels=['E','D','C','B','A'])
# Out:
# <ipython-input-68-2ead0cffc0cc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final['Grade']=pd.cut(final['% Renewable'],bins=5,labels=['E','D','C','B','A'])

# %%
q12 = final.join(cont)

# %%
q12
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %%
grouped_q12=q12.groupby(['Continent', 'Grade']).agg({'Rank': 'count'})

# %%
grouped_q12.columns=['count']

# %%
grouped_q12
# Out:
#                      count
# Continent     Grade
# Asia          E          4
#               D          1
#               C          0
#               B          0
#               A          0
# Australia     E          1
#               D          0
#               C          0
#               B          0
#               A          0
# Europe        E          1
#               D          3
#               C          2
#               B          0
#               A          0
# North America E          1
#               D          0
#               C          0
#               B          0
#               A          1
# South America E          0
#               D          0
#               C          0
#               B          0
#               A          1

# %%
grouped_q12[grouped_q12['count']>0]
# Out:
#                      count
# Continent     Grade
# Asia          E          4
#               D          1
# Australia     E          1
# Europe        E          1
#               D          3
#               C          2
# North America E          1
#               A          1
# South America A          1

# %% [markdown]
# # Plotting

# %%
ax = final.plot(x='Rank', y='% Renewable', kind='scatter', xticks=range(1,16), figsize=[16,6]);

for i, txt in enumerate(final.index):
    ax.annotate(txt, [final['Rank'][i], final['% Renewable'][i]])
